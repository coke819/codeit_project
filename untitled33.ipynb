# %% [markdown]
# <a href="https://colab.research.google.com/github/coke819/codeit_project/blob/main/untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (18.1.0)

# %%
import pandas as pd
df= pd.read_parquet('/content/drive/MyDrive/고급프로젝트/final.parquet')

# %%
df.shape, df.head(10)
# Out:
# ((11406944, 12),
#                                 event_id      event_datetime  \
#  0  00000533-3f1c-4b3b-81f1-0c8f35754b4e 2023-07-18 19:40:17
#  1  00114c10-8321-4978-a73f-fd452162b9f2 2023-07-31 19:11:51
#  2  01f136ac-3257-4cf9-b0a9-c0c37fe7e572 2023-07-31 19:14:34
#  3  02cc364e-23ec-46cf-a02f-14cf60f97ec1 2023-07-31 19:13:18
#  4  05d05a79-cdb3-43fe-b931-5cb0992a36a1 2023-07-31 19:12:50
#  5  088d75f8-4fd0-4a26-8aaf-67298b5bdf54 2023-07-31 19:13:28
#  6  0c4f13aa-a989-46b9-b714-a1959ead58ed 2023-07-31 19:15:21
#  7  0d75e82e-1ae4-443c-b36d-35b7c1c90c4c 2023-07-31 19:12:25
#  8  0f0ee486-04c9-48b3-a826-d10d1b535e88 2023-07-31 19:12:26
#  9  10c0e8d3-8e78-4ba8-8bf6-b3d0c4918204 2023-07-31 19:15:28
#
#                            event_key                    session_id  \
#  0                    $session_start  4OzYh3seq3VKytpSn5pvQkZNQii1
#  1               click_notice_detail  4OzYh3seq3VKytpSn5pvQkZNQii1
#  2               click_question_open  4OzYh3seq3VKytpSn5pvQkZNQii1
#  3               click_question_open  4OzYh3seq3VKytpSn5pvQkZNQii1
#  4               click_question_open  4OzYh3seq3VKytpSn5pvQkZNQii1
#  5               click_question_open  4OzYh3seq3VKytpSn5pvQkZNQii1
#  6  click_bottom_navigation_timeline  4OzYh3seq3VKytpSn5pvQkZNQii1
#  7                      view_lab_tap  4OzYh3seq3VKytpSn5pvQkZNQii1
#  8   click_bottom_navigation_profile  4OzYh3seq3VKytpSn5pvQkZNQii1
#  9                  view_profile_tap  4OzYh3seq3VKytpSn5pvQkZNQii1
#
#     friend_count  question_id  heart_balance      id  user_id  \
#  0           NaN          NaN            NaN  367093  1041414
#  1          51.0          NaN         1719.0  367093  1041414
#  2          51.0          NaN         1719.0  367093  1041414
#  3          51.0          NaN         1719.0  367093  1041414
#  4          51.0          NaN         1719.0  367093  1041414
#  5          51.0          NaN         1719.0  367093  1041414
#  6          51.0          NaN         1719.0  367093  1041414
#  7          51.0          NaN         1719.0  367093  1041414
#  8          51.0          NaN         1719.0  367093  1041414
#  9          51.0          NaN         1719.0  367093  1041414
#
#                                device_id osname osversion
#  0  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  1  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  2  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  3  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  4  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  5  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  6  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  7  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  8  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0
#  9  590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74    iOS      16.0  )

# %%
df['device_id'].value_counts()
# Out:
# device_id
# A40CA2FA-CEB6-4E94-857D-7C229ECC2598    8157
# cfa76079-ab4e-4ea1-a7df-38ceaa5ef011    6551
# cc4a2268-2923-49aa-ab07-0e71bba6482c    6548
# b1b6f602-17ce-4636-9eff-bf0ad5578c5a    5714
# 6f2a1743-5513-405c-8425-ce11efe267b2    5684
#                                         ...
# 0A5AC1BD-A802-43CA-8AC2-ED91805673F2       1
# 333bb382-61a1-47e0-bb7d-f5a649548fee       1
# E9129887-140C-4554-A5D4-C4B061D3AAD6       1
# 6B9FABA5-AD7A-42EE-89A4-E735C001F9C1       1
# 1C8AFAFF-C24F-4F1F-9D6B-DF329E55B892       1
# Name: count, Length: 242118, dtype: int64

# %%
df1= df.drop(columns={'osname','osversion','question_id','id'})

# %%
df1
# Out:
#                                       event_id      event_datetime  \
# 0         00000533-3f1c-4b3b-81f1-0c8f35754b4e 2023-07-18 19:40:17
# 1         00114c10-8321-4978-a73f-fd452162b9f2 2023-07-31 19:11:51
# 2         01f136ac-3257-4cf9-b0a9-c0c37fe7e572 2023-07-31 19:14:34
# 3         02cc364e-23ec-46cf-a02f-14cf60f97ec1 2023-07-31 19:13:18
# 4         05d05a79-cdb3-43fe-b931-5cb0992a36a1 2023-07-31 19:12:50
# ...                                        ...                 ...
# 11406939  fcc5da6e-6aff-4bad-afaa-387266dd3b2e 2023-07-21 08:07:34
# 11406940  fdb9051e-fc66-419d-b086-b6ecf8b34157 2023-07-21 08:07:34
# 11406941  fcd2ca57-88fc-48e5-b7cc-6ed78de0458f 2023-07-28 01:29:54
# 11406942  fd1c8cbc-a857-405b-96dd-dfa4533e6875 2023-08-05 17:10:41
# 11406943  ff6ae0d2-63df-40af-b326-a501da233cce 2023-08-05 17:10:41
#
#                     event_key                            session_id  \
# 0              $session_start          4OzYh3seq3VKytpSn5pvQkZNQii1
# 1         click_notice_detail          4OzYh3seq3VKytpSn5pvQkZNQii1
# 2         click_question_open          4OzYh3seq3VKytpSn5pvQkZNQii1
# 3         click_question_open          4OzYh3seq3VKytpSn5pvQkZNQii1
# 4         click_question_open          4OzYh3seq3VKytpSn5pvQkZNQii1
# ...                       ...                                   ...
# 11406939       $session_start          3TA8FC93pgMMo9DXIfF6ZyrFWK82
# 11406940           launch_app          3TA8FC93pgMMo9DXIfF6ZyrFWK82
# 11406941           launch_app  2AD0A3A2-BE39-4C48-8AD4-9A0D2B651C13
# 11406942       $session_start          rj9ILcLEjiS3XWEkkC9yXxhGPnR2
# 11406943           launch_app          rj9ILcLEjiS3XWEkkC9yXxhGPnR2
#
#           friend_count  heart_balance                       user_id  \
# 0                  NaN            NaN                       1041414
# 1                 51.0         1719.0                       1041414
# 2                 51.0         1719.0                       1041414
# 3                 51.0         1719.0                       1041414
# 4                 51.0         1719.0                       1041414
# ...                ...            ...                           ...
# 11406939           NaN            NaN  3TA8FC93pgMMo9DXIfF6ZyrFWK82
# 11406940           NaN            NaN  3TA8FC93pgMMo9DXIfF6ZyrFWK82
# 11406941           NaN            NaN  HPzICnO0CyUSylk0GpET2HQpxDD3
# 11406942           NaN          501.0  rj9ILcLEjiS3XWEkkC9yXxhGPnR2
# 11406943           NaN          501.0  rj9ILcLEjiS3XWEkkC9yXxhGPnR2
#
#                                      device_id
# 0         590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74
# 1         590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74
# 2         590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74
# 3         590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74
# 4         590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74
# ...                                        ...
# 11406939  A71D24D6-8627-4BAD-8943-3EA0F176A6CE
# 11406940  A71D24D6-8627-4BAD-8943-3EA0F176A6CE
# 11406941  2AD0A3A2-BE39-4C48-8AD4-9A0D2B651C13
# 11406942  00545FE7-0DDF-4835-9F53-62CABF631D6F
# 11406943  00545FE7-0DDF-4835-9F53-62CABF631D6F
#
# [11406944 rows x 8 columns]

# %%
df1.isnull().sum()
# Out:
# event_id               0
# event_datetime         0
# event_key              0
# session_id             0
# friend_count      720352
# heart_balance     696462
# user_id                0
# device_id              0
# dtype: int64

# %%
df2 = df1[['session_id', 'event_key', 'event_datetime', 'heart_balance','user_id']].copy()
df2 = df2.sort_values(['session_id', 'event_datetime'])

#이전 하트 잔액, 이벤트 키, 시간 계산
df2['heart_balance_prev'] = df2.groupby('session_id')['heart_balance'].shift(1)
df2['event_key_prev'] = df2.groupby('session_id')['event_key'].shift(1)
df2['event_datetime_prev'] = df2.groupby('session_id')['event_datetime'].shift(1)

#변화량 계산 공식
df2['heart_balance_diff'] = df2['heart_balance'] - df2['heart_balance_prev']

#NaN 이전 값을 채우기
df2['heart_balance'] = df2['heart_balance'].fillna(method='ffill')

#NaN 제거 & 변화가 있는 경우만 골라내기
result_df2 = df2[
    df2['heart_balance_diff'].notnull() &
    (df2['heart_balance_diff'] != 0)
].copy()



#원하는 컬럼만 정리
result_df2 = result_df2[[
    'session_id',
    'event_key_prev', 'event_datetime_prev', 'heart_balance_prev',
    'event_key', 'event_datetime', 'heart_balance',
    'heart_balance_diff','user_id'
]]

result_df2.head()
# Out:
# <ipython-input-60-3373779198>:13: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#                                     session_id  event_key_prev  \
# 3112338   001398E9-BBCE-4F6E-A669-6A9D72C77CE5      view_login
# 3112360   001398E9-BBCE-4F6E-A669-6A9D72C77CE5       view_shop
# 3112330   001398E9-BBCE-4F6E-A669-6A9D72C77CE5       view_shop
# 11031785  0014f001-4757-48cf-a626-6bf17e910d26  $session_start
# 3052805   0018ED87-EA58-43B1-9C77-B0809BE89B85  $session_start
#
#          event_datetime_prev  heart_balance_prev  \
# 3112338  2023-07-23 17:51:05                95.0
# 3112360  2023-07-23 17:53:28               108.0
# 3112330  2023-07-23 17:53:44                12.0
# 11031785 2023-07-21 20:09:10              1891.0
# 3052805  2023-07-19 11:01:05               323.0
#
#                                   event_key      event_datetime  \
# 3112338   click_bottom_navigation_questions 2023-07-23 17:51:13
# 3112360                    click_attendance 2023-07-23 17:53:32
# 3112330                      click_purchase 2023-07-23 17:53:45
# 11031785          click_appbar_alarm_center 2023-07-21 20:09:18
# 3052805   click_bottom_navigation_questions 2023-07-19 11:01:09
#
#           heart_balance  heart_balance_diff  user_id
# 3112338           108.0                13.0  1172696
# 3112360            12.0               -96.0  1172696
# 3112330           212.0               200.0  1172696
# 11031785         2184.0               293.0  1115814
# 3052805            86.0              -237.0  1037318

# %%
events= result_df2.copy()

# %%
from google.colab import drive
drive.mount('/content/drive')

save_path = '/content/drive/My Drive/고급프로젝트/events.csv'
events.to_csv(save_path, index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df2.isnull().sum()
# Out:
# session_id                  0
# event_key                   0
# event_datetime              0
# heart_balance               0
# heart_balance_prev     921212
# event_key_prev         242445
# event_datetime_prev    242445
# heart_balance_diff     923857
# dtype: int64

# %%
df2.shape
# Out:
# (11406944, 8)

# %%
df2.duplicated().sum()
# Out:
# np.int64(39025)

# %%
df2_clean = df2.dropna(subset=[
    'heart_balance_prev',
    'heart_balance_diff',
    'event_key_prev',
    'event_datetime_prev'
])

# %%
df2_clean.shape
# Out:
# (10483087, 8)

# %%
df2_clean.isnull().sum()
# Out:
# session_id             0
# event_key              0
# event_datetime         0
# heart_balance          0
# heart_balance_prev     0
# event_key_prev         0
# event_datetime_prev    0
# heart_balance_diff     0
# dtype: int64

# %%
df2_clean.head(10)
# Out:
#                                    session_id                  event_key  \
# 2896285  00025EE1-BA46-4853-8FDD-B991FABA328F             $session_start
# 2896247  00025EE1-BA46-4853-8FDD-B991FABA328F                 launch_app
# 2896276  00025EE1-BA46-4853-8FDD-B991FABA328F  click_appbar_alarm_center
# 2896275  00025EE1-BA46-4853-8FDD-B991FABA328F        click_notice_detail
# 2896259  00025EE1-BA46-4853-8FDD-B991FABA328F        click_notice_detail
# 2896272  00025EE1-BA46-4853-8FDD-B991FABA328F        click_notice_detail
# 2896254  00025EE1-BA46-4853-8FDD-B991FABA328F        click_notice_detail
# 2896265  00025EE1-BA46-4853-8FDD-B991FABA328F                 launch_app
# 2896266  00025EE1-BA46-4853-8FDD-B991FABA328F             $session_start
# 2896288  00025EE1-BA46-4853-8FDD-B991FABA328F       click_question_start
#
#              event_datetime  heart_balance  heart_balance_prev  \
# 2896285 2023-07-22 23:30:09          210.0               210.0
# 2896247 2023-07-22 23:30:31          210.0               210.0
# 2896276 2023-07-22 23:30:39          210.0               210.0
# 2896275 2023-07-22 23:30:48          210.0               210.0
# 2896259 2023-07-22 23:30:58          210.0               210.0
# 2896272 2023-07-22 23:31:11          210.0               210.0
# 2896254 2023-07-22 23:31:13          210.0               210.0
# 2896265 2023-07-24 11:54:02          210.0               210.0
# 2896266 2023-07-24 11:54:02          210.0               210.0
# 2896288 2023-07-24 11:54:07          210.0               210.0
#
#                     event_key_prev event_datetime_prev  heart_balance_diff
# 2896285                 launch_app 2023-07-22 23:30:09                 0.0
# 2896247             $session_start 2023-07-22 23:30:09                 0.0
# 2896276                 launch_app 2023-07-22 23:30:31                 0.0
# 2896275  click_appbar_alarm_center 2023-07-22 23:30:39                 0.0
# 2896259        click_notice_detail 2023-07-22 23:30:48                 0.0
# 2896272        click_notice_detail 2023-07-22 23:30:58                 0.0
# 2896254        click_notice_detail 2023-07-22 23:31:11                 0.0
# 2896265        click_notice_detail 2023-07-22 23:31:13                 0.0
# 2896266                 launch_app 2023-07-24 11:54:02                 0.0
# 2896288             $session_start 2023-07-24 11:54:02                 0.0

# %%
df2
# Out:
#                                     session_id  \
# 2896253   00025EE1-BA46-4853-8FDD-B991FABA328F
# 2896285   00025EE1-BA46-4853-8FDD-B991FABA328F
# 2896247   00025EE1-BA46-4853-8FDD-B991FABA328F
# 2896276   00025EE1-BA46-4853-8FDD-B991FABA328F
# 2896275   00025EE1-BA46-4853-8FDD-B991FABA328F
# ...                                        ...
# 10890498          zzzPTZp5ttgt5M0gs6R5B4NNKbC3
# 10890502          zzzPTZp5ttgt5M0gs6R5B4NNKbC3
# 10890507          zzzPTZp5ttgt5M0gs6R5B4NNKbC3
# 10890487          zzzPTZp5ttgt5M0gs6R5B4NNKbC3
# 10890493          zzzPTZp5ttgt5M0gs6R5B4NNKbC3
#
#                                   event_key      event_datetime  \
# 2896253                          launch_app 2023-07-22 23:30:09
# 2896285                      $session_start 2023-07-22 23:30:09
# 2896247                          launch_app 2023-07-22 23:30:31
# 2896276           click_appbar_alarm_center 2023-07-22 23:30:39
# 2896275                 click_notice_detail 2023-07-22 23:30:48
# ...                                     ...                 ...
# 10890498                 view_questions_tap 2023-07-28 22:35:31
# 10890502                  view_timeline_tap 2023-07-28 22:35:31
# 10890507  click_bottom_navigation_questions 2023-07-28 22:35:32
# 10890487   click_bottom_navigation_timeline 2023-07-28 22:35:35
# 10890493                  view_timeline_tap 2023-07-28 22:35:35
#
#           heart_balance  heart_balance_prev  \
# 2896253           210.0                 NaN
# 2896285           210.0               210.0
# 2896247           210.0               210.0
# 2896276           210.0               210.0
# 2896275           210.0               210.0
# ...                 ...                 ...
# 10890498         1481.0              1481.0
# 10890502         1481.0              1481.0
# 10890507         1481.0              1481.0
# 10890487         1481.0              1481.0
# 10890493         1481.0              1481.0
#
#                              event_key_prev event_datetime_prev  \
# 2896253                                 NaN                 NaT
# 2896285                          launch_app 2023-07-22 23:30:09
# 2896247                      $session_start 2023-07-22 23:30:09
# 2896276                          launch_app 2023-07-22 23:30:31
# 2896275           click_appbar_alarm_center 2023-07-22 23:30:39
# ...                                     ...                 ...
# 10890498                       view_lab_tap 2023-07-28 22:35:31
# 10890502                 view_questions_tap 2023-07-28 22:35:31
# 10890507                  view_timeline_tap 2023-07-28 22:35:31
# 10890487  click_bottom_navigation_questions 2023-07-28 22:35:32
# 10890493   click_bottom_navigation_timeline 2023-07-28 22:35:35
#
#           heart_balance_diff
# 2896253                  NaN
# 2896285                  0.0
# 2896247                  0.0
# 2896276                  0.0
# 2896275                  0.0
# ...                      ...
# 10890498                 0.0
# 10890502                 0.0
# 10890507                 0.0
# 10890487                 0.0
# 10890493                 0.0
#
# [11406944 rows x 8 columns]

# %%
#NaN 제거 & 변화가 있는 경우만 골라내기
result_df3 = df2_clean[
    df2_clean['heart_balance_diff'].notnull() &
    (df2_clean['heart_balance_diff'] != 0)
].copy()



#원하는 컬럼만 정리
result_df3 = result_df3[[
    'session_id',
    'event_key_prev', 'event_datetime_prev', 'heart_balance_prev',
    'event_key', 'event_datetime', 'heart_balance',
    'heart_balance_diff'
]]

result_df3.head()
# Out:
#                                     session_id  event_key_prev  \
# 3112338   001398E9-BBCE-4F6E-A669-6A9D72C77CE5      view_login
# 3112360   001398E9-BBCE-4F6E-A669-6A9D72C77CE5       view_shop
# 3112330   001398E9-BBCE-4F6E-A669-6A9D72C77CE5       view_shop
# 11031785  0014f001-4757-48cf-a626-6bf17e910d26  $session_start
# 3052805   0018ED87-EA58-43B1-9C77-B0809BE89B85  $session_start
#
#          event_datetime_prev  heart_balance_prev  \
# 3112338  2023-07-23 17:51:05                95.0
# 3112360  2023-07-23 17:53:28               108.0
# 3112330  2023-07-23 17:53:44                12.0
# 11031785 2023-07-21 20:09:10              1891.0
# 3052805  2023-07-19 11:01:05               323.0
#
#                                   event_key      event_datetime  \
# 3112338   click_bottom_navigation_questions 2023-07-23 17:51:13
# 3112360                    click_attendance 2023-07-23 17:53:32
# 3112330                      click_purchase 2023-07-23 17:53:45
# 11031785          click_appbar_alarm_center 2023-07-21 20:09:18
# 3052805   click_bottom_navigation_questions 2023-07-19 11:01:09
#
#           heart_balance  heart_balance_diff
# 3112338           108.0                13.0
# 3112360            12.0               -96.0
# 3112330           212.0               200.0
# 11031785         2184.0               293.0
# 3052805            86.0              -237.0

# %%
result_df3.shape
# Out:
# (74921, 8)

# %%
result_df3.isnull().sum()
# Out:
# session_id             0
# event_key_prev         0
# event_datetime_prev    0
# heart_balance_prev     0
# event_key              0
# event_datetime         0
# heart_balance          0
# heart_balance_diff     0
# dtype: int64

# %%
# 충전 이벤트만 추출 (하트 증가가 있는 경우)
charge_df = result_df3[result_df3['heart_balance_diff'] > 0].copy()

# 충전 전 이벤트
charge_df['prev_event'] = charge_df['event_key_prev']
# 충전 후 이벤트
charge_df['next_event'] = charge_df['event_key']

# 충전 전후 이벤트 쌍으로 퍼널 구성
funnel_df = charge_df[['session_id', 'event_datetime_prev', 'prev_event', 'event_datetime', 'next_event', 'heart_balance_diff']]
funnel_df
# Out:
#                                     session_id event_datetime_prev  \
# 3112338   001398E9-BBCE-4F6E-A669-6A9D72C77CE5 2023-07-23 17:51:05
# 3112330   001398E9-BBCE-4F6E-A669-6A9D72C77CE5 2023-07-23 17:53:44
# 11031785  0014f001-4757-48cf-a626-6bf17e910d26 2023-07-21 20:09:10
# 4630691   00199e33-2998-4052-b3b1-21fec14459c4 2023-08-06 22:43:31
# 4630778   00199e33-2998-4052-b3b1-21fec14459c4 2023-08-09 01:02:02
# ...                                        ...                 ...
# 6066198           zzGb11TvaoMrtQQ3hIrjteIWUJk2 2023-07-23 17:41:37
# 3037147           zzM1vj0lTSaztBEYG8yoV8NptCC3 2023-07-29 21:52:33
# 3851386           zzMKV6lSglYfjuAqqBa1vX3eoGN2 2023-07-26 17:11:34
# 1579022           zzmejla6kTSFw2iDl00M44BPRMb2 2023-08-03 00:03:34
# 5655              zzs9GsFAvyXJRhU2BqwaGS0iCVp2 2023-07-23 14:28:11
#
#               prev_event      event_datetime  \
# 3112338       view_login 2023-07-23 17:51:13
# 3112330        view_shop 2023-07-23 17:53:45
# 11031785  $session_start 2023-07-21 20:09:18
# 4630691       view_login 2023-08-06 22:43:47
# 4630778       launch_app 2023-08-09 01:03:34
# ...                  ...                 ...
# 6066198   $session_start 2023-07-23 17:41:54
# 3037147       view_login 2023-07-29 21:52:47
# 3851386       launch_app 2023-07-26 17:11:38
# 1579022       view_login 2023-08-03 00:03:41
# 5655          view_login 2023-07-23 14:28:17
#
#                                  next_event  heart_balance_diff
# 3112338   click_bottom_navigation_questions                13.0
# 3112330                      click_purchase               200.0
# 11031785          click_appbar_alarm_center               293.0
# 4630691                   view_timeline_tap               105.0
# 4630778                           view_shop               130.0
# ...                                     ...                 ...
# 6066198                click_question_share               500.0
# 3037147                 click_question_open               179.0
# 3851386    click_bottom_navigation_timeline               200.0
# 1579022                   view_timeline_tap               439.0
# 5655      click_bottom_navigation_questions                31.0
#
# [43919 rows x 6 columns]

# %%
# 충전 전후 행동쌍 만들어서 개수 집계
transition_counts = charge_df.groupby(['prev_event', 'next_event']).size().reset_index(name='count')

# count 기준으로 상위 10개 보기
top_transitions = transition_counts.sort_values(by='count', ascending=False).head(10)

top_transitions
# Out:
#          prev_event                         next_event  count
# 147      view_login                click_question_open   7636
# 176       view_shop                     click_purchase   2770
# 113      launch_app                click_question_open   2322
# 136      view_login          click_appbar_alarm_center   2185
# 148      view_login               click_question_start   1462
# 157      view_login                  view_timeline_tap   1296
# 115      launch_app               click_question_start   1185
# 143      view_login  click_bottom_navigation_questions   1096
# 30   $session_start                click_question_open   1072
# 104      launch_app                   click_attendance   1054

# %%
DF = df1[['user_id', 'event_key', 'event_datetime', 'heart_balance']].copy()
DF = df1.sort_values(['user_id', 'event_datetime'])

#이전 하트 잔액, 이벤트 키, 시간 계산
DF['heart_balance_prev'] = DF.groupby('user_id')['heart_balance'].shift(1)
DF['event_key_prev'] = DF.groupby('user_id')['event_key'].shift(1)
DF['event_datetime_prev'] = DF.groupby('user_id')['event_datetime'].shift(1)

#변화량 계산 공식
DF['heart_balance_diff'] = DF['heart_balance'] - DF['heart_balance_prev']

#NaN 이전 값을 채우기
DF['heart_balance'] = DF['heart_balance'].fillna(method='ffill')

#NaN 제거 & 변화가 있는 경우만 골라내기
result_DF = DF[
    DF['heart_balance_diff'].notnull() &
    (DF['heart_balance_diff'] != 0)
].copy()



#원하는 컬럼만 정리
result_DF = result_DF[[
    'user_id',
    'event_key_prev', 'event_datetime_prev', 'heart_balance_prev',
    'event_key', 'event_datetime', 'heart_balance',
    'heart_balance_diff'
]]

result_DF.head()
# Out:
# <ipython-input-22-518431995>:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   DF['heart_balance'] = DF['heart_balance'].fillna(method='ffill')
#          user_id event_key_prev event_datetime_prev  heart_balance_prev  \
# 7119300  1000013     view_login 2023-07-20 01:04:42              3688.0
# 1393712  1000030      view_shop 2023-07-29 01:01:09               771.0
# 1393656  1000030     launch_app 2023-07-30 15:55:00               547.0
# 3282467  1000044     launch_app 2023-07-18 18:08:53              1136.0
# 9573354  1000069      view_shop 2023-07-20 21:53:46              1058.0
#
#                                 event_key      event_datetime  heart_balance  \
# 7119300  click_bottom_navigation_timeline 2023-07-20 01:04:57         3718.0
# 1393712                    click_purchase 2023-07-29 01:01:11          547.0
# 1393656                  click_attendance 2023-07-30 15:55:03          771.0
# 3282467                        launch_app 2023-07-18 22:57:35          883.0
# 9573354                        launch_app 2023-07-20 21:54:47          571.0
#
#          heart_balance_diff
# 7119300                30.0
# 1393712              -224.0
# 1393656               224.0
# 3282467              -253.0
# 9573354              -487.0

# %%
# 충전 전후 행동쌍 만들어서 개수 집계
charge_df = result_DF[result_DF['heart_balance_diff'] > 0].copy()
charge_df['prev_event'] = charge_df['event_key_prev']
# 충전 후 이벤트
charge_df['next_event'] = charge_df['event_key']
transition_counts = charge_df.groupby(['prev_event', 'next_event']).size().reset_index(name='count')

# count 기준으로 상위 10개 보기
top_transitions2= transition_counts.sort_values(by='count', ascending=False).head(10)

top_transitions2
# Out:
#          prev_event                         next_event  count
# 181      view_login                click_question_open   7636
# 220       view_shop                     click_purchase   2770
# 144      launch_app                click_question_open   2322
# 170      view_login          click_appbar_alarm_center   2185
# 182      view_login               click_question_start   1462
# 191      view_login                  view_timeline_tap   1296
# 146      launch_app               click_question_start   1185
# 177      view_login  click_bottom_navigation_questions   1096
# 31   $session_start                click_question_open   1072
# 135      launch_app                   click_attendance   1054

# %%
import plotly.graph_objects as go

# 전체 노드 리스트 만들기
all_nodes = list(set(top_transitions['prev_event']).union(set(top_transitions['next_event'])))
node_indices = {node: i for i, node in enumerate(all_nodes)}

# 노드 인덱스 매핑
source_indices = top_transitions['prev_event'].map(node_indices)
target_indices = top_transitions['next_event'].map(node_indices)
values = top_transitions['count']

# Sankey 다이어그램 생성
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        label=all_nodes,
    ),
    link=dict(
        source=source_indices,
        target=target_indices,
        value=values
    ))])

fig.update_layout(title_text="충전 전후 행동 전이 (Transition Sankey)", font_size=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="86b9e144-ff66-4f76-8ca4-e1ac97d561b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86b9e144-ff66-4f76-8ca4-e1ac97d561b6")) {                    Plotly.newPlot(                        "86b9e144-ff66-4f76-8ca4-e1ac97d561b6",                        [{"link":{"source":[0,1,2,0,0,0,2,0,7,2],"target":[10,9,10,4,6,3,6,8,10,5],"value":[7636,2770,2322,2185,1462,1296,1185,1096,1072,1054]},"node":{"label":["view_login","view_shop","launch_app","view_timeline_tap","click_appbar_alarm_center","click_attendance","click_question_start","$session_start","click_bottom_navigation_questions","click_purchase","click_question_open"],"pad":15,"thickness":20},"type":"sankey"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marke ...

# %%
import pandas as pd

top_prev = transition_counts['prev_event'].value_counts().head(10).index
top_next = transition_counts['next_event'].value_counts().head(10).index

filtered_heatmap = transition_counts[
    transition_counts['prev_event'].isin(top_prev) &
    transition_counts['next_event'].isin(top_next)
]

# 피벗 테이블 (cross-tab 형태로)
heatmap_data = pd.pivot_table(
    filtered_heatmap,
    values='count',
    index='prev_event',
    columns='next_event',
    aggfunc='sum',
    fill_value=0
)

# %%
pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 47.0 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Downloading scikit_learn-1.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 19.5 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.0 which is incompatible.
# Successfully installed scikit-learn-1.7.0

# %%
# 충전 전 행동 분포
prev_behavior_counts = charge_df['event_key_prev'].value_counts(normalize=True)

# 충전 후 행동 분포
next_behavior_counts = charge_df['event_key'].value_counts(normalize=True)

# 변화량 정리
behavior_change = (next_behavior_counts - prev_behavior_counts).sort_values(ascending=False)
behavior_change
# Out:
# click_question_open                  0.254523
# click_appbar_alarm_center            0.082125
# click_question_start                 0.082013
# view_timeline_tap                    0.072541
# click_attendance                     0.071127
# click_purchase                       0.062284
# click_bottom_navigation_questions    0.057032
# $session_end                         0.036136
# click_appbar_chat_rooms              0.035014
# click_bottom_navigation_timeline     0.034812
# view_lab_tap                         0.034453
# click_bottom_navigation_profile      0.026283
# click_bottom_navigation_lab          0.014297
# view_profile_tap                     0.008978
# click_question_ask                   0.006756
# click_question_share                 0.002963
# click_appbar_friend_plus             0.002738
# view_questions_tap                   0.000673
# click_notice_detail                  0.000269
# click_random_ask_normal              0.000022
# click_profile_ask                    0.000000
# click_random_ask_other               0.000000
# complete_signup                     -0.000022
# click_timeline_chat_start           -0.000022
# click_random_ask_shuffle            -0.000022
# skip_question                       -0.000157
# click_appbar_setting                -0.000224
# complete_question                   -0.000471
# view_shop                           -0.139426
# launch_app                          -0.166068
# $session_start                      -0.167909
# view_login                          -0.411860
# click_friend_invite                       NaN
# click_invite_friend                       NaN
# complete_purchase                         NaN
# view_home_tap                             NaN
# view_signup                               NaN
# Name: proportion, dtype: float64

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
behavior_change.sort_values().plot(kind='barh', color='skyblue')
plt.axvline(0, color='gray', linewidth=0.8)
plt.title('충전 전후 행동의 변화량')
plt.xlabel('변화량(비율)')
plt.ylabel('행동(Event Key)')
plt.grid(True, axis='x')
plt.tight_layout()
plt.show()

# %%
result_DF
# Out:
#          user_id                   event_key_prev event_datetime_prev  \
# 7119300  1000013                       view_login 2023-07-20 01:04:42
# 1393712  1000030                        view_shop 2023-07-29 01:01:09
# 1393656  1000030                       launch_app 2023-07-30 15:55:00
# 3282467  1000044                       launch_app 2023-07-18 18:08:53
# 9573354  1000069                        view_shop 2023-07-20 21:53:46
# ...          ...                              ...                 ...
# 9952327   999940                       view_login 2023-07-18 19:33:34
# 8425700   999946                   $session_start 2023-07-19 01:43:07
# 6991192   999976                   $session_start 2023-07-18 12:36:27
# 6991177   999976  click_bottom_navigation_profile 2023-07-18 12:42:27
# 9672993   999990                       view_login 2023-07-23 03:18:27
#
#          heart_balance_prev                         event_key  \
# 7119300              3688.0  click_bottom_navigation_timeline
# 1393712               771.0                    click_purchase
# 1393656               547.0                  click_attendance
# 3282467              1136.0                        launch_app
# 9573354              1058.0                        launch_app
# ...                     ...                               ...
# 9952327               898.0               click_question_open
# 8425700              2256.0         click_appbar_alarm_center
# 6991192               224.0                        launch_app
# 6991177                24.0                    $session_start
# 9672993               823.0               click_question_open
#
#              event_datetime  heart_balance  heart_balance_diff
# 7119300 2023-07-20 01:04:57         3718.0                30.0
# 1393712 2023-07-29 01:01:11          547.0              -224.0
# 1393656 2023-07-30 15:55:03          771.0               224.0
# 3282467 2023-07-18 22:57:35          883.0              -253.0
# 9573354 2023-07-20 21:54:47          571.0              -487.0
# ...                     ...            ...                 ...
# 9952327 2023-07-18 19:33:49          707.0              -191.0
# 8425700 2023-07-19 01:43:18         1089.0             -1167.0
# 6991192 2023-07-18 12:37:08           24.0              -200.0
# 6991177 2023-07-19 22:23:45          224.0               200.0
# 9672993 2023-07-23 03:18:43          129.0              -694.0
#
# [76239 rows x 8 columns]

# %%
user_recharge = result_DF.groupby('user_id').apply(lambda x: (x['heart_balance_diff'] > 0).any()).reset_index()
user_recharge.columns = ['user_id', 'did_recharge']
# Out:
# <ipython-input-31-988302537>:1: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
user_recharge
# Out:
#        user_id  did_recharge
# 0      1000013          True
# 1      1000030          True
# 2      1000044         False
# 3      1000069          True
# 4      1000079          True
# ...        ...           ...
# 38987   999920         False
# 38988   999940         False
# 38989   999946         False
# 38990   999976          True
# 38991   999990         False
#
# [38992 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

save_path = '/content/drive/My Drive/고급프로젝트/user_recharge.csv'
user_recharge.to_csv(save_path, index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 충전 이벤트만 필터링 (하트 증가 기준)
charge_df = result_DF[result_DF['heart_balance_diff'] > 0].copy()

# 세션별로 충전 시점 이후 행동 추적
conversion_behaviors = [
    'click_question_open',
    'click_question_start',
    'click_appbar_alarm_center'
]

# 충전 이후 행동 탐지 함수 정의
def detect_post_charge_behavior(df_user):
    df_user = df_user.reset_index(drop=True)
    charge_times = df_user[df_user['heart_balance_diff'] > 0]['event_datetime']
    if charge_times.empty:
        return pd.Series({b: False for b in conversion_behaviors})
    first_charge_time = charge_times.iloc[0]
    post_charge = df_user[df_user['event_datetime'] > first_charge_time]
    return pd.Series({
        b: (post_charge['event_key'] == b).any() for b in conversion_behaviors
    })

# user 기준 행동 추적
user_flags = result_DF.groupby('user_id').apply(detect_post_charge_behavior).reset_index()

# suer별 충전 횟수 계산
user_charge_counts = charge_df['user_id'].value_counts().rename('charge_count').reset_index()
user_charge_counts.columns = ['user_id', 'charge_count']
user_flags = user_flags.merge(user_charge_counts, on='user_id', how='left')
user_flags['charge_count'] = user_flags['charge_count'].fillna(0).astype(int)
user_flags['is_recharged'] = user_flags['charge_count'] > 1

# 재충전율 계산
summary = []
for b in conversion_behaviors:
    group = user_flags.groupby(user_flags[b])['is_recharged'].mean()
    summary.append({'behavior': b, 'did_action': True, 'recharge_rate': group.get(True, 0)})
    summary.append({'behavior': b, 'did_action': False, 'recharge_rate': group.get(False, 0)})

recharge_df = pd.DataFrame(summary)
# Out:
# <ipython-input-34-2032826772>:24: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
recharge_df
# Out:
#                     behavior  did_action  recharge_rate
# 0        click_question_open        True       0.813591
# 1        click_question_open       False       0.115905
# 2       click_question_start        True       0.812436
# 3       click_question_start       False       0.150257
# 4  click_appbar_alarm_center        True       0.789386
# 5  click_appbar_alarm_center       False       0.164241

# %%
user_sequences = (
    df1
    .sort_values(['user_id', 'event_datetime'])
    .groupby('user_id')['event_key']
    .apply(list)
    .reset_index()
)

# %%
user_sequences['user_str']= user_sequences['event_key'].apply(lambda x: '>'.join(x))

# %%
#문자열 시퀀스를 숫자 벡터로 변환
# TF-IDF란? 는 흔한 행동은 가중치를 줄이고, 드문 행동은 가중치를 높이는 것=> 각 세션을 행동 기반의 고차원 벡터로 바꿔주는 작업
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(user_sequences['user_str'])

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
user_sequences['cluster'] = kmeans.fit_predict(X)

# %%
for c in sorted(user_sequences['cluster'].unique()):
    print(f"\nCluster {c} 대표 시퀀스:")
    print(user_sequences[user_sequences['cluster'] == c]['user_str'].head(3).to_string(index=False))
# Out:
# Cluster 0 대표 시퀀스:
# launch_app>$session_start>click_question_open>c...
# launch_app>click_bottom_navigation_timeline>cli...
# launch_app>$session_start>launch_app>launch_app...
#
# Cluster 1 대표 시퀀스:
# launch_app>$session_start>$session_end>$session...
# $session_start>launch_app>click_question_open>c...
# launch_app>$session_start>$session_end>$session...
#
# Cluster 2 대표 시퀀스:
# $session_start>launch_app
# launch_app>$session_start
# launch_app>$session_start
#
# Cluster 3 대표 시퀀스:
#            launch_app>$session_start>view_home_tap
# launch_app>$session_start>$session_end>launch_a...
# launch_app>$session_start>view_home_tap>$sessio...
#
# Cluster 4 대표 시퀀스:
# $session_end>$session_start>launch_app>$session...
# $session_start>launch_app>$session_end>launch_a...
# launch_app>$session_end>$session_start>$session...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# user_sequences에는 다음 컬럼이 있다고 가정: cluster, user_str

def visualize_cluster_sequences_grid(user_sequences, top_n=5, n_cols=3):
    clusters = sorted(user_sequences['cluster'].unique())
    n_clusters = len(clusters)

    # subplot 크기 자동 계산
    n_rows = math.ceil(n_clusters / n_cols)

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(7*n_cols, 4*n_rows))
    axes = axes.flatten()

    for idx, c in enumerate(clusters):
        cluster_data = user_sequences[user_sequences['cluster'] == c]
        top_seq = cluster_data['user_str'].value_counts().head(top_n)

        sns.barplot(
            x=top_seq.values, y=top_seq.index, ax=axes[idx],
            hue=top_seq.index, palette="Blues_r", dodge=False, legend=False
        )
        axes[idx].set_title(f"Cluster {c} Top {top_n}")
        axes[idx].set_xlabel("Count")
        axes[idx].set_ylabel("Sequence")
        axes[idx].set_xlim(0, top_seq.values.max() * 1.2)
    # 빈 subplot 숨기기
    for ax in axes[len(clusters):]:
        ax.axis('off')

    plt.subplots_adjust(hspace= 1.0, wspace=0.9)
    plt.show()


# 실행 예시
visualize_cluster_sequences_grid(user_sequences, top_n=5, n_cols=2)

# %%
user_sequences
# Out:
#                              user_id  \
# 0       012Si5t33QgB3g18oOpcd2RDx5U2
# 1       01BFWYlo11eFmY64kiY6n5PQAcs1
# 2       01pPQO7oPmgKZOU7f8XGc93rCWg2
# 3       02Ika66GtzVQj5Epl6xtwcGf72u1
# 4       02QVyNBCraNN7i04MPRQVrGbGPR2
# ...                              ...
# 239645  zy74pTORXyYJPQ9DVIg42cYFpuE3
# 239646  zyZTSupKTMaxZyJKmilGZNMmsMh2
# 239647  zyk1fC4t2BW230b2pB1AvD5Y2rk2
# 239648  zzc8rg7phYQqQDm8EWia0ZMMxLE2
# 239649  zzggGjI3IrcP5CslbG9WlzgouC42
#
#                                                 event_key  \
# 0                            [$session_start, launch_app]
# 1                            [launch_app, $session_start]
# 2                            [launch_app, $session_start]
# 3                            [$session_start, launch_app]
# 4       [launch_app, $session_start, $session_end, lau...
# ...                                                   ...
# 239645                       [launch_app, $session_start]
# 239646                       [$session_start, launch_app]
# 239647                       [launch_app, $session_start]
# 239648  [launch_app, $session_start, $session_end, vie...
# 239649  [$session_end, $session_start, launch_app, vie...
#
#                                                  user_str  cluster
# 0                               $session_start>launch_app        2
# 1                               launch_app>$session_start        2
# 2                               launch_app>$session_start        2
# 3                               $session_start>launch_app        2
# 4       launch_app>$session_start>$session_end>launch_...        2
# ...                                                   ...      ...
# 239645                          launch_app>$session_start        2
# 239646                          $session_start>launch_app        2
# 239647                          launch_app>$session_start        2
# 239648  launch_app>$session_start>$session_end>view_ho...        2
# 239649  $session_end>$session_start>launch_app>view_ho...        2
#
# [239650 rows x 4 columns]

# %%
user_cluster_mapping = user_sequences[['user_id', 'cluster']]
user_cluster_mapping
# Out:
#                              user_id  cluster
# 0       012Si5t33QgB3g18oOpcd2RDx5U2        2
# 1       01BFWYlo11eFmY64kiY6n5PQAcs1        2
# 2       01pPQO7oPmgKZOU7f8XGc93rCWg2        2
# 3       02Ika66GtzVQj5Epl6xtwcGf72u1        2
# 4       02QVyNBCraNN7i04MPRQVrGbGPR2        2
# ...                              ...      ...
# 239645  zy74pTORXyYJPQ9DVIg42cYFpuE3        2
# 239646  zyZTSupKTMaxZyJKmilGZNMmsMh2        2
# 239647  zyk1fC4t2BW230b2pB1AvD5Y2rk2        2
# 239648  zzc8rg7phYQqQDm8EWia0ZMMxLE2        2
# 239649  zzggGjI3IrcP5CslbG9WlzgouC42        2
#
# [239650 rows x 2 columns]

# %%
# 가입일
signup_date = df.groupby('user_id')['event_datetime'].min().reset_index().rename(columns={'event_datetime': 'signup_date'})

# 최근 접속일
last_login = df.groupby('user_id')['event_datetime'].max().reset_index().rename(columns={'event_datetime': 'last_login'})

# 이벤트 수 (활동량)
event_count = df.groupby('user_id').size().reset_index(name='event_count')

# friend_count (마지막 friend_count로 대체)
friend_count = df.groupby('user_id')['friend_count'].last().reset_index()

# 디바이스 OS 정보 (마지막 사용 OS)
os_info = df.groupby('user_id')[['osname', 'osversion']].last().reset_index()

# user_profile 종합
user_profile = signup_date.merge(last_login, on='user_id') \
                           .merge(event_count, on='user_id') \
                           .merge(friend_count, on='user_id') \
                           .merge(os_info, on='user_id')

# 확인
user_profile.head()
# Out:
#                         user_id         signup_date          last_login  \
# 0  012Si5t33QgB3g18oOpcd2RDx5U2 2023-07-25 12:59:58 2023-07-25 12:59:58
# 1  01BFWYlo11eFmY64kiY6n5PQAcs1 2023-07-18 20:45:12 2023-07-18 20:45:12
# 2  01pPQO7oPmgKZOU7f8XGc93rCWg2 2023-07-25 22:15:41 2023-07-25 22:15:41
# 3  02Ika66GtzVQj5Epl6xtwcGf72u1 2023-07-20 21:59:56 2023-07-20 21:59:56
# 4  02QVyNBCraNN7i04MPRQVrGbGPR2 2023-07-21 08:59:54 2023-07-24 00:01:15
#
#    event_count  friend_count   osname osversion
# 0            2           NaN  Android        12
# 1            2           NaN      iOS    16.5.1
# 2            2           NaN      iOS      16.4
# 3            2           NaN      iOS      16.0
# 4            6           NaN  Android        11

# %%
merged_df= pd.merge(user_cluster_mapping, user_profile, on= 'user_id',how= 'left')

# %%
merged_df
# Out:
#                              user_id  cluster         signup_date  \
# 0       012Si5t33QgB3g18oOpcd2RDx5U2        2 2023-07-25 12:59:58
# 1       01BFWYlo11eFmY64kiY6n5PQAcs1        2 2023-07-18 20:45:12
# 2       01pPQO7oPmgKZOU7f8XGc93rCWg2        2 2023-07-25 22:15:41
# 3       02Ika66GtzVQj5Epl6xtwcGf72u1        2 2023-07-20 21:59:56
# 4       02QVyNBCraNN7i04MPRQVrGbGPR2        2 2023-07-21 08:59:54
# ...                              ...      ...                 ...
# 239645  zy74pTORXyYJPQ9DVIg42cYFpuE3        2 2023-07-21 10:48:48
# 239646  zyZTSupKTMaxZyJKmilGZNMmsMh2        2 2023-07-18 23:31:55
# 239647  zyk1fC4t2BW230b2pB1AvD5Y2rk2        2 2023-08-07 16:14:42
# 239648  zzc8rg7phYQqQDm8EWia0ZMMxLE2        2 2023-07-27 21:08:48
# 239649  zzggGjI3IrcP5CslbG9WlzgouC42        2 2023-08-03 01:02:02
#
#                 last_login  event_count  friend_count   osname osversion
# 0      2023-07-25 12:59:58            2           NaN  Android        12
# 1      2023-07-18 20:45:12            2           NaN      iOS    16.5.1
# 2      2023-07-25 22:15:41            2           NaN      iOS      16.4
# 3      2023-07-20 21:59:56            2           NaN      iOS      16.0
# 4      2023-07-24 00:01:15            6           NaN  Android        11
# ...                    ...          ...           ...      ...       ...
# 239645 2023-07-21 10:48:48            2           NaN      iOS      16.1
# 239646 2023-07-18 23:31:55            2           NaN      iOS    16.0.3
# 239647 2023-08-07 16:14:42            2           NaN      iOS    16.5.1
# 239648 2023-07-27 21:08:50            5           NaN      iOS    15.0.2
# 239649 2023-08-03 01:02:03            5           NaN  Android        13
#
# [239650 rows x 8 columns]

# %%
merged_df.shape
# Out:
# (239650, 8)

# %%
merged_df.isnull().sum()
# Out:
# user_id             0
# cluster             0
# signup_date         0
# last_login          0
# event_count         0
# friend_count    17987
# osname              0
# osversion           0
# dtype: int64

# %%
# "친구수를 기록하지 않은 유저 = 친구 없음으로 간주"
merged_df['friend_count']=merged_df['friend_count'].fillna(0)

# %%
merged_df
# Out:
#                              user_id  cluster         signup_date  \
# 0       012Si5t33QgB3g18oOpcd2RDx5U2        2 2023-07-25 12:59:58
# 1       01BFWYlo11eFmY64kiY6n5PQAcs1        2 2023-07-18 20:45:12
# 2       01pPQO7oPmgKZOU7f8XGc93rCWg2        2 2023-07-25 22:15:41
# 3       02Ika66GtzVQj5Epl6xtwcGf72u1        2 2023-07-20 21:59:56
# 4       02QVyNBCraNN7i04MPRQVrGbGPR2        2 2023-07-21 08:59:54
# ...                              ...      ...                 ...
# 239645  zy74pTORXyYJPQ9DVIg42cYFpuE3        2 2023-07-21 10:48:48
# 239646  zyZTSupKTMaxZyJKmilGZNMmsMh2        2 2023-07-18 23:31:55
# 239647  zyk1fC4t2BW230b2pB1AvD5Y2rk2        2 2023-08-07 16:14:42
# 239648  zzc8rg7phYQqQDm8EWia0ZMMxLE2        2 2023-07-27 21:08:48
# 239649  zzggGjI3IrcP5CslbG9WlzgouC42        2 2023-08-03 01:02:02
#
#                 last_login  event_count  friend_count   osname osversion
# 0      2023-07-25 12:59:58            2           0.0  Android        12
# 1      2023-07-18 20:45:12            2           0.0      iOS    16.5.1
# 2      2023-07-25 22:15:41            2           0.0      iOS      16.4
# 3      2023-07-20 21:59:56            2           0.0      iOS      16.0
# 4      2023-07-24 00:01:15            6           0.0  Android        11
# ...                    ...          ...           ...      ...       ...
# 239645 2023-07-21 10:48:48            2           0.0      iOS      16.1
# 239646 2023-07-18 23:31:55            2           0.0      iOS    16.0.3
# 239647 2023-08-07 16:14:42            2           0.0      iOS    16.5.1
# 239648 2023-07-27 21:08:50            5           0.0      iOS    15.0.2
# 239649 2023-08-03 01:02:03            5           0.0  Android        13
#
# [239650 rows x 8 columns]

# %%
merged_df.isnull().sum()
# Out:
# user_id         0
# cluster         0
# signup_date     0
# last_login      0
# event_count     0
# friend_count    0
# osname          0
# osversion       0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 클러스터별 가입 시기 차이
merged_df.groupby('cluster')['signup_date'].agg(['min', 'max', 'median'])
# Out:
#                         min                 max                  median
# cluster
# 0       2023-07-18 00:00:00 2023-08-10 23:52:59 2023-07-21 16:43:21.000
# 1       2023-07-18 00:00:00 2023-08-10 23:57:36 2023-07-23 18:08:44.000
# 2       2023-07-18 00:00:01 2023-08-10 23:59:54 2023-07-23 13:33:31.500
# 3       2023-07-18 00:00:00 2023-08-10 23:57:25 2023-07-21 07:54:47.500
# 4       2023-07-18 00:00:00 2023-08-10 23:59:37 2023-07-26 16:56:17.000

# %%
#"Cluster별 활동량 (이벤트 수)"
merged_df.groupby('cluster')['event_count'].mean()
# Out:
# cluster
# 0    111.095506
# 1     57.322454
# 2      8.974539
# 3     35.312238
# 4     56.601889
# Name: event_count, dtype: float64

# %%
#"Cluster별 친구수 차이"
merged_df.groupby('cluster')['friend_count'].mean()
# Out:
# cluster
# 0    53.487938
# 1    59.724107
# 2    37.442382
# 3    58.572978
# 4    57.129930
# Name: friend_count, dtype: float64

# %%
merged_df.groupby(['cluster', 'osname']).size().unstack(fill_value=0)
# Out:
# osname   Android    iOS
# cluster
# 0           7352  10804
# 1          11135  22262
# 2          13017  30737
# 3          13788  37282
# 4          28070  65203

# %%
from google.colab import drive
drive.mount('/content/drive')

save_path = '/content/drive/My Drive/고급프로젝트/merged_df.csv'
merged_df.to_csv(save_path, index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
